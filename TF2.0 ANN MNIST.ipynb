# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

(x_train,y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train/255.0, x_test/255.0
print("X_train shape", x_train.shape)
# Out:
# X_train shape (60000, 28, 28)

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Flatten(input_shape=(28,28)),
                                    tf.keras.layers.Dense(128,activation='relu'),
                                    tf.keras.layers.Dropout(0.2),
                                    tf.keras.layers.Dense(10,activation="softmax")
])

# %%
model.compile(optimizer="adam",
              loss = "sparse_categorical_crossentropy",
              metrics = ['accuracy'])

# %%
r1 = model.fit(x_train,y_train, 
               validation_data = (x_test,y_test),
               epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2966 - accuracy: 0.9134 - val_loss: 0.1372 - val_accuracy: 0.9579
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1423 - accuracy: 0.9570 - val_loss: 0.0979 - val_accuracy: 0.9706
# Epoch 3/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1069 - accuracy: 0.9682 - val_loss: 0.0839 - val_accuracy: 0.9743
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0863 - accuracy: 0.9733 - val_loss: 0.0772 - val_accuracy: 0.9752
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0750 - accuracy: 0.9760 - val_loss: 0.0726 - val_accuracy: 0.9769
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0669 - accuracy: 0.9785 - val_loss: 0.0694 - val_accuracy: 0.9785
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0595 - accuracy: 0.9806 - val_loss: 0.0712 - val_accuracy: 0.9791
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0533 - accuracy: 0.9828 - val_loss: 0.0728 - val_accuracy: 0.9781
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0495 - accuracy: 0.9837 - val_loss: 0.0698 - val_accuracy: 0.9793
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0436 - accuracy: 0.9856 - val_loss: 0.0664 - val_accuracy: 0.9796

# %%
import matplotlib.pyplot as plt
plt.plot(r1.history['loss'],label='loss')
plt.plot(r1.history['val_loss'],label='val_loss')
plt.legend()

# %%
plt.plot(r1.history['accuracy'],label='acc')
plt.plot(r1.history['val_accuracy'],label='val_acc')
plt.legend()

# %%
print(model.evaluate(x_test,y_test))
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0664 - accuracy: 0.9796
# [0.06636867672204971, 0.9796000123023987]
