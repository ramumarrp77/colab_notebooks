# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10*np.pi, 1000)
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0-rc2

# %%
# !ls
# Out:
# sample_data

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
 from google.colab import files
 uploaded = files.upload()
# Out:
#      <input type="file" id="files-0be959d0-e7d1-4064-9943-6310a687f86e" name="files[]" multiple disabled />
#      <output id="result-0be959d0-e7d1-4064-9943-6310a687f86e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bank.csv to bank.csv

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/"
# Out:
# '15081429151HM Meeting  20.10.17 (1).doc'
# 'Abstract template (1).docx'
# 'Abstract template (1).gdoc'
# 'Abstract template (2).docx'
# 'Abstract template.docx'
# 'Abstract template.gdoc'
#  acc.cpp
#  AI_2018_Unit1_Part3_Search-Uninformed.gdoc
#  AI_2018_Unit1_Part3_Search-Uninformed.pdf
#  ALF_0771.JPG
#  ALF_0779.JPG
#  ALF_0784.JPG
# 'Applications of Machine Learning-converted.pptx'
# 'Applying ML to create intelligent systems.gslides'
# 'Applying ML to create intelligent systems.pptx'
#  ASK-ME.gslides
# 'Automatic Highlights Generator.gslides'
#  bird.gdoc
# 'Branch_SSN_Student data sheet_UG & PG_2020 Batch (1).gsheet'
# 'Branch_SSN_Student data sheet_UG & PG_2020 Batch.gsheet'
# 'Branch_SSN_Student data sheet_UG & PG_2020 Batch.xls'
# 'CDLab01 (1).gdoc'
# 'CDLab01 (2).gdoc'
#  CDLab01.gdoc
#  CDLab01.pdf
#  cellphone.cpp
# 'Circular - Merit Scholarship.pdf'
# 'Cognizant 2020 Batch Test Shortlist.xlsx'
# 'Cognizant Selection Process - 2020 Batch _ Registered students datasheet (1).gsheet'
# 'Cognizant Selection Process - 2020 Batch _ Registered students datasheet.gsheet'
# 'Cognizant Selection Process - 2020 Batch _ Registered students datasheet.xls'
# 'Colab Notebooks'
# 'Committee List New.gdoc'
#  const_example.cpp
#  construct.cpp
# 'Contact Details.gform'
# 'Contact Details (Responses).gsheet'
# 'DNN Applications 27 Sep 2019.pptx'
#  download.wav
#  dynnamic.cpp
#  EC6801_WC_Unit1_Class1.pptx
#  EC6801_WC_Unit1_Class2.pdf
#  employee.cpp
#  FARM-CART.gslides
# 'Friss_Equation (1).pdf'
# 'FYP Conclusion.gdoc'
# 'FYP Implementation.gdoc'
# 'FYP Intro.gdoc'
# 'FYP Literature Survery.gdoc'
# 'FYP Result.gdoc'
# 'FYP System Design.gdoc'
# 'Getting started.pdf'
# 'Goldman sachs - Previous year questions.docx'
# 'Hacquest Students Participation.gsheet'
# 'Hacquest Students Participation.xlsx'
# 'H & T 2.0 OD.gsheet'
# 'IMS LOGO (1).gdoc'
# 'IMS LOGO.doc'
# 'IMS LOGO.gdoc'
#  inheri_eg3.cpp
#  inheri_exam2.cpp
#  inheri_exam.cpp
# 'Intro to NN.pptx'
#  local_class.cpp
# 'Match Videos'
# 'MLworkshop photos'
# 'MSD Selection process 17 Aug.gsheet'
# 'MSD Selection process 17 Aug.xlsx'
#  mul.cpp
#  Multipath.cpp
#  NewDelete.cpp
#  operator_overload.cpp
# 'Photos IT-A'
# 'Photos IT-B'
# 'Placement Training - 2020 Batch - Internship List (1).gsheet'
# 'Placement Training - 2020 Batch - Internship List.gsheet'
# 'Placement Training - 2020 Batch - Internship List.xlsx'
# 'Ram Resume.pdf'
# 'Report Final.gdoc'
#  Resume.pdf
# 'Runup detection'
#  SANJAYVR.gdoc
#  Screenshot
# 'Software design talk - Atendees.xlsx'
#  SSN_27thSep2019.pptx
# 'SSN_Buddimake_2020 Batch.gsheet'
# 'SSN_Buddimake_2020 Batch.xls'
# 'SSN_Goldman Sachs_2020 Batch.xls'
# 'SSN pres template - Final.ppt'
# 'ssn-shortlists (1).gsheet'
#  ssn-shortlists.gsheet
#  ssn-shortlists.xlsx
#  static_example.cpp
# 'structural  design pattern...docx'
#  tcpechoclient.c
#  tcpechoserver.c
# 'Two-Ray GR Model.pdf'
# 'Udemy - Machine Learning A-Z - Hands-On Python & R In Data Science'
# 'Unit V-2b. Spatial_Multiplexing_Part_II.pdf'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
#  vivid
# 'vivid (1)'
# 'VIVID Main.gslides'
#  vp

# %%
# !ls gdrive
# Out:
# 'My Drive'

# %%
# !ls
# Out:
# bank.csv  gdrive  sample_data

# %%
uploaded
# Out:
# {'bank.csv': b'"age";"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"\n30;"unemployed";"married";"primary";"no";1787;"no";"no";"cellular";19;"oct";79;1;-1;0;"unknown";"no"\n33;"services";"married";"secondary";"no";4789;"yes";"yes";"cellular";11;"may";220;1;339;4;"failure";"no"\n35;"management";"single";"tertiary";"no";1350;"yes";"no";"cellular";16;"apr";185;1;330;1;"failure";"no"\n30;"management";"married";"tertiary";"no";1476;"yes";"yes";"unknown";3;"jun";199;4;-1;0;"unknown";"no"\n59;"blue-collar";"married";"secondary";"no";0;"yes";"no";"unknown";5;"may";226;1;-1;0;"unknown";"no"\n35;"management";"single";"tertiary";"no";747;"no";"no";"cellular";23;"feb";141;2;176;3;"failure";"no"\n36;"self-employed";"married";"tertiary";"no";307;"yes";"no";"cellular";14;"may";341;1;330;2;"other";"no"\n39;"technician";"married";"secondary";"no";147;"yes";"no";"cellular";6;"may";151;2;-1;0;"unknown";"no"\n41;"entrepreneur";"married";"tertiary";"no";221;"yes";"no";"unknown";14;"may";57;2;-1;0;"unknown";"no"\n43;"services";"married";"primary";"no";-88;"yes";"yes";"cellular";17;"apr";313;1;147;2;"failure";"no"\n39;"services";"married";"secondary";"no";9374;"yes";"no";"unknown";20;"may";273;1;-1;0;"unknown";"no"\n43;"admin.";"married";"secondary";"no";264;"yes";"no";"cellular";17;"apr";113;2;-1;0;"unknown";"no"\n36;"technician";"married";"tertiary";"no";1109;"no";"no";"cellular";13;"aug";328;2;-1;0;"unknown";"no"\n20;"student";"single";"secondary";"no";502;"no";"no";"cellular";30;"apr";261;1;-1;0;"unknown";"yes"\n31;"blue-collar";"married";"secondary";"no";360;"yes";"yes";"cellular";29;"jan";89;1;241;1;"failure";"no"\n40;"management";"married";"tertiary";"no";194;"no";"yes";"cellular";29;"aug";189;2;-1;0;"unknown";"no"\n56;"technician";"married";"secondary";"no";4073;"no";"no";"cellular";27;"aug";239;5;-1;0;"unknown";"no"\n37;"admin.";"single";"tertiary";"no";2317;"yes";"no";"cellular";20;"apr";114;1;152;2;"failure";"no"\n25;"blue-collar";"single";"primary";"no";-221;"yes";"no";"unknown";23;"may";250;1;-1;0;"unknown";"no"\n31;"services";"married";"secondary";"no";132;"no";"no";"cellular";7;"jul";148;1;152;1;"other";"no"\n38;"management";"divorced";"unknown";"no";0;"yes";"no";"cellular";18;"nov";96;2;-1;0;"unknown";"no"\n42;"management";"divorced";"tertiary";"no";16;"no";"no";"cellular";19;"nov";140;3;-1;0;"unknown";"no"\n44;"services";"single";"secondary";"no";106;"no";"no";"unknown";12;"jun";109;2;-1;0;"unknown";"no"\n44;"entrepreneur";"married";"secondary";"no";93;"no";"no";"cellular";7;"jul";125;2;-1;0;"unknown";"no"\n26;"housemaid";"married";"tertiary";"no";543;"no";"no";"cellular";30;"jan";169;3;-1;0;"unknown";"no"\n41;"management";"married";"tertiary";"no";5883;"no";"no";"cellular";20;"nov";182;2;-1;0;"unknown";"no"\n55;"blue-collar";"married";"primary";"no";627;"yes";"no";"unknown";5;"may";247;1;-1;0;"unknown";"no"\n67;"retired";"married";"unknown";"no";696;"no";"no";"telephone";17;"aug";119;1;105;2;"failure";"no"\n56;"self-employed";"married";"secondary";"no";784;"no";"yes";"cellular";30;"jul";149;2;-1;0;"unknown";"no"\n53;"admin.";"married";"secondary";"no";105;"no";"yes";"cellular";21;"aug";74;2;-1;0;"unknown";"no"\n68;"retired";"divorced";"secondary";"no";4189;"no";"no";"telephone";14;"jul";897;2;-1;0;"unknown";"yes"\n31;"technician";"married";"secondary";"no";171;"no";"no";"cellular";27;"aug";81;3;-1;0;"unknown";"no"\n59;"management";"married";"secondary";"no";42;"no";"no";"cellular";21;"nov";40;1;-1;0;"unknown";"no"\n32;"management";"single";"tertiary";"no";2536;"yes";"no";"cellular";26;"aug";958;6;-1;0;"unknown";"yes"\n49;"technician";"married";"tertiary";"no";1235;"no";"no";"cellular";13;"aug";354;3;-1;0;"unknown";"yes"\n42;"admin.";"divorced";"secondary";"no";1811;"yes";"no";"unknown";14;"may";150;1;-1;0;"unknown";"no"\n78;"retired";"divorced";"primary";"no";229;"no";"no";"telephone";22;"oct";97;1;-1;0;"unknown";"yes"\n32;"blue-collar"; ...
